# %%
import numpy as np
import pandas as pd

# %% [markdown]
# # 데이터 불러오기

# %%
key = pd.read_csv('data/keyword.csv',index_col='Unnamed: 0')
key
# Out:
#     keyword
# 0        언론
# 1       20대
# 2        초선
# 3        개혁
# 4        선거
# ..      ...
# 544      마련
# 545      하루
# 546      1,
# 547      58
# 548      뛰어
#
# [549 rows x 1 columns]

# %%
pledge = pd.read_csv('data/pledge.csv',index_col='Unnamed: 0')
pledge
# Out:
#    name                                          pledge
# 0   박영선                21분 생활권 도시 서울, 세계 디지털 경제수도 서울 구현
# 1   박영선  21분안에 주거, 직장, 쇼핑., 여가, 건강, 의료, 교육, 보육이 해결되는 도시
# 2   박영선                                   강남 강북 균형발전 추진
# 3   박영선                                    대전환펀드 1조원 구성
# 4   박영선   블록체인 기술 기반 KS코인 운용. Al,5G 등 철단기술이 융합된 경제도시 조성
# ..  ...                                             ...
# 92  박형준                                  저출산 예산 1조원대 증액
# 93  박형준                               정자,난자 보관은행 운영사업추진
# 94  박형준                                  영유마 돌봄 확대사업 추진
# 95  박형준                                        팸테크밸리 조성
# 96  박형준                                     청년신용불량 구제지원
#
# [97 rows x 2 columns]

# %% [markdown]
# # 후보공약의 keyword 개수만큼 keyword_count 증가

# %%
# count list 생성
count = [0]*len(pledge)

# 후보공약에 키워드가 있으면 count 증가
for i in range(len(pledge['pledge'])):
    # print('---'*30)
    for j in range(len(key['keyword'])):
        # print(key['keyword'].iloc[j])
        if key['keyword'].iloc[j] in pledge['pledge'].iloc[i]:
            print(f"포함 키워드 : {key['keyword'].iloc[j]}")
            print(f"공약 : {pledge['pledge'].iloc[i]}")
            count[i] += 1
count
# Out:
# 포함 키워드 : 서울
# 공약 : 21분 생활권 도시 서울, 세계 디지털 경제수도 서울 구현
# 포함 키워드 : 수도
# 공약 : 21분 생활권 도시 서울, 세계 디지털 경제수도 서울 구현
# 포함 키워드 : 경제
# 공약 : 21분 생활권 도시 서울, 세계 디지털 경제수도 서울 구현
# 포함 키워드 : 해결
# 공약 : 21분안에 주거, 직장, 쇼핑., 여가, 건강, 의료, 교육, 보육이 해결되는 도시
# 포함 키워드 : 추진
# 공약 : 강남 강북 균형발전 추진
# 포함 키워드 : 경제
# 공약 : 블록체인 기술 기반 KS코인 운용. Al,5G 등 철단기술이 융합된 경제도시 조성
# 포함 키워드 : 서울
# 공약 : 집 격정 없는 서울, 클러스터 중심 일자리창출과 서울형 창업생태계 조성
# 포함 키워드 : 일자리
# 공약 : 집 격정 없는 서울, 클러스터 중심 일자리창출과 서울형 창업생태계 조성
# 포함 키워드 : 자리
# 공약 : 집 격정 없는 서울, 클러스터 중심 일자리창출과 서울형 창업생태계 조성
# 포함 키워드 : 30
# 공약 : 평당 천만원 반값아파트 공공주택 30만호 공급
# 포함 키워드 : 주택
# 공약 : 평당 천만원 반값아파트 공공주택 30만호 공급
# 포함 키워드 : 아파트
# 공약 : 평당 천만원 반값아파트 공공주택 30만호 공급
# 포함 키워드 : 청년
# 공약 : 청년 등 전월세 보증금 무이자 지원, 최저주거기준 주택 개선자금 지원
# 포함 키워드 : 보증금
# 공약 : 청년 등 전월세 보증금 무이자 지원, 최저주거기준 주택 개선자금 지원
# 포함 키워드 : 지원
# 공약 : 청년 등 전월세 보증금 무이자 지원, 최저주거기준 주택 개선자금 지원
# 포함 키워드 : 월세
# 공약 : 청년 등 전월세 보증금 무이자 지원, 최저주거기준 주택 개선자금 지원
# 포함 키워드 : 주택
# 공약 : 청년 등 전월세 보증금 무이자 지원, 최저주거기준 주택 개선자금 지원
# 포함 키워드 : 30
# 공약 : 소상공인 임대료 30% 감면, 임대업자 15% 시비 지원
# 포함 키워드 : 지원
# 공약 : 소상공인 임대료 30% 감면, 임대업자 15% 시비 지원
# 포함 키워드 : 15
# 공약 : 소상공인 임대료 30% 감면, 임대업자 15% 시비 지원
# 포함 키워드 : 임대
# 공약 : 소상공인 임대료 30% 감면, 임대업자 15% 시비 지원
# 포함 키워드 : 소상공인
# 공약 : 소상공인 임대료 30% 감면, 임대업자 15% 시비 지원
# 포함 키워드 : 지원
# 공약 : 특수고용직, 플랫폼노동자, 프리랜서 등 고용보험료 지원
# 포함 키워드 : 노동
# 공약 : 특수고용직, 플랫폼노동자, 프리랜서 등 고용보험료 지원
# 포함 키워드 : 환경
# 공약 : 기후와 환경, 교통 대전환
# 포함 키워드 : 2,
# 공약 : 지하철 1,2,4호선 경의중앙선 지상구간 지하화
# 포함 키워드 : 1,
# 공약 : 지하철 1,2,4호선 경의중앙선 지상구간 지하화
# 포함 키워드 : 30
# 공약 : 2030년부터 내연차 신규등록 금지
# 포함 키워드 : 금지
# 공약 : 2030년부터 내연차 신규등록 금지
# 포함 키워드 : 서울
# 공약 : 대상별 맞춤형 돌봄과 교육으로 건강하고 행복한 공동체 서울
# 포함 키워드 : 추진
# 공약 : 유치원 전면 무상급식 추진-어린이집 교사대비 아동비율 개선
# 포함 키워드 : 서울
# 공약 : 재난과 위기에 강한 서울, 세계 문화의 새로운 중심 서울
# 포함 키워드 : 재난
# 공약 : 재난과 위기에 강한 서울, 세계 문화의 새로운 중심 서울
# 포함 키워드 : 지원
# 공약 : 문화 패스 카드 도입과 확대, 예술인 고용산재보험 가입지원
# 포함 키워드 : 시민
# 공약 : 시민주도형 재난안전 협의체 구성등으로 안전관리체계 개편
# 포함 키워드 : 관리
# 공약 : 시민주도형 재난안전 협의체 구성등으로 안전관리체계 개편
# 포함 키워드 : 재난
# 공약 : 시민주도형 재난안전 협의체 구성등으로 안전관리체계 개편
# 포함 키워드 : 부동산
# 공약 : 주택공급 활성화로 부동산 시장 안정화
# 포함 키워드 : 시장
# 공약 : 주택공급 활성화로 부동산 시장 안정화
# 포함 키워드 : 주택
# 공약 : 주택공급 활성화로 부동산 시장 안정화
# 포함 키워드 : 1년
# 공약 : 1년내 서울시 도시계획규제 혁파
# 포함 키워드 : 서울
# 공약 : 1년내 서울시 도시계획규제 혁파
# 포함 키워드 : 규제
# 공약 : 1년내 서울시 도시계획규제 혁파
# 포함 키워드 : 추진
# 공약 : 재개발, 재건축 정상화로 18.5만호 추진동력 확보
# 포함 키워드 : 주택
# 공약 : 도심형타운하우스 모아주택 도입으로 3만호 공급
# 포함 키워드 : 모아
# 공약 : 도심형타운하우스 모아주택 도입으로 3만호 공급
# 포함 키워드 : 주택
# 공약 : 장기전세주택 시즌2 상생주택으로 7만호 공급
# 포함 키워드 : 추진
# 공약 : 율곡로 도로구조개선사업 보행로 신속조성추진
# 포함 키워드 : 일자리
# 공약 : 동북권, 서남권, 서북권 등 권역별 일자리, 상업, 교통, 교육 등 핵심시설을 유치하여 지역균형발전 달성
# 포함 키워드 : 자리
# 공약 : 동북권, 서남권, 서북권 등 권역별 일자리, 상업, 교통, 교육 등 핵심시설을 유치하여 지역균형발전 달성
# 포함 키워드 : 핵심
# 공약 : 동북권, 서남권, 서북권 등 권역별 일자리, 상업, 교통, 교육 등 핵심시설을 유치하여 지역균형발전 달성
# 포함 키워드 : 서울
# 공약 : 서울혁신파크 고품격 경제문화타운 재조성
# 포함 키워드 : 경제
# 공약 : 서울혁신파크 고품격 경제문화타운 재조성
# 포함 키워드 : 2.
# 공약 : 영등포~금천을 잇는 서남권 경제거점벨트 2.0조성
# 포함 키워드 : 경제
# 공약 : 영등포~금천을 잇는 서남권 경제거점벨트 2.0조성
# 포함 키워드 : 수도
# 공약 : 창동일대를 동북지역과 북부수도권 대장주로
# 포함 키워드 : 조직
# 공약 : 매트릭스형 TF조직
# 포함 키워드 : 프로
# 공약 : 취업교육-취업과 창업-자산형성-내집 마련으로 이어지는 실질적이고 전방위적인 터널탈출 프로젝트
# 포함 키워드 : 취업
# 공약 : 취업교육-취업과 창업-자산형성-내집 마련으로 이어지는 실질적이고 전방위적인 터널탈출 프로젝트
# 포함 키워드 : 마련
# 공약 : 취업교육-취업과 창업-자산형성-내집 마련으로 이어지는 실질적이고 전방위적인 터널탈출 프로젝트
# 포함 키워드 : 청년
# 공약 : 4차 산업형 청년 취업사관학교 설립
# 포함 키워드 : 취업
# 공약 : 4차 산업형 청년 취업사관학교 설립
# 포함 키워드 : 취업
# 공약 : 취업,창업 특강 라이브 제공
# 포함 키워드 : 청년
# 공약 : 청년 자산불림 컨설팅 서울 영테크
# 포함 키워드 : 서울
# 공약 : 청년 자산불림 컨설팅 서울 영테크
# 포함 키워드 : 청년
# 공약 : 청년 주거안정 위한 청년 월세지원 확대
# 포함 키워드 : 지원
# 공약 : 청년 주거안정 위한 청년 월세지원 확대
# 포함 키워드 : 월세
# 공약 : 청년 주거안정 위한 청년 월세지원 확대
# 포함 키워드 : 청년
# 공약 : 청년 몽땅 정보통 제공
# 포함 키워드 : 일자리
# 공약 : 일자리 넘치는 글로벌 경제플랫폼 도시
# 포함 키워드 : 경제
# 공약 : 일자리 넘치는 글로벌 경제플랫폼 도시
# 포함 키워드 : 자리
# 공약 : 일자리 넘치는 글로벌 경제플랫폼 도시
# 포함 키워드 : 30
# 공약 : 가덕신공항 2029년 완공, 2030 월드엑스포 유치성공
# 포함 키워드 : 부산
# 공약 : 가덕신공항-부산신항-철도 트라이포트 물류 시스템 구축
# 포함 키워드 : 경제
# 공약 : 북항, 영도 일원까지 경제자유구역 확대 지정
# 포함 키워드 : 좋은
# 공약 : 우량 공공기관 유치, 중견,대기업 유치로 좋은 일자리 창출
# 포함 키워드 : 일자리
# 공약 : 우량 공공기관 유치, 중견,대기업 유치로 좋은 일자리 창출
# 포함 키워드 : 자리
# 공약 : 우량 공공기관 유치, 중견,대기업 유치로 좋은 일자리 창출
# 포함 키워드 : 좋은
# 공약 : 안전하고 살기 좋은 녹색도시
# 포함 키워드 : 지도
# 공약 : 안전하고 쾌적한 보행로 조성 및 디지털 보행지도 구축
# 포함 키워드 : 수도
# 공약 : 스마트 수도 관리시스템 구축
# 포함 키워드 : 관리
# 공약 : 스마트 수도 관리시스템 구축
# 포함 키워드 : 주택
# 공약 : 공공주택 5만호 공급
# 포함 키워드 : 사람
# 공약 : 사람종심 친환경 대중교통 시스템 구축
# 포함 키워드 : 환경
# 공약 : 사람종심 친환경 대중교통 시스템 구축
# 포함 키워드 : 프로
# 공약 : 천문대 프로젝트 (천명 마을문화 활동가 지원사업)
# 포함 키워드 : 지원
# 공약 : 천문대 프로젝트 (천명 마을문화 활동가 지원사업)
# 포함 키워드 : 부산
# 공약 : 영화도시 부산 브랜드 문화상품화
# 포함 키워드 : 부산
# 공약 : 스포츠 생활문화 도시 부산
# 포함 키워드 : 청년
# 공약 : 청년문화도시 조성
# 포함 키워드 : 코로나
# 공약 : 코로나19 국난극복과 공공의료체계 구축
# 포함 키워드 : 시민
# 공약 : 재난손실 소상공인 지원 및 부산시민소득 시행
# 포함 키워드 : 지원
# 공약 : 재난손실 소상공인 지원 및 부산시민소득 시행
# 포함 키워드 : 부산
# 공약 : 재난손실 소상공인 지원 및 부산시민소득 시행
# 포함 키워드 : 소상공인
# 공약 : 재난손실 소상공인 지원 및 부산시민소득 시행
# 포함 키워드 : 재난
# 공약 : 재난손실 소상공인 지원 및 부산시민소득 시행
# 포함 키워드 : 시민
# 공약 : 시민중심 자치분권 도시
# 포함 키워드 : 부산
# 공약 : 부산해양특별자치시 설치 추진
# 포함 키워드 : 추진
# 공약 : 부산해양특별자치시 설치 추진
# 포함 키워드 : 부산
# 공약 : 부산시정협의회 운영
# 포함 키워드 : 시민
# 공약 : 시민참여형 시정 확립으로 신뢰받는 시정 구현
# 포함 키워드 : 청년
# 공약 : 주민참여 예산제 확대 및 청년 참여 예산제 도입
# 포함 키워드 : 청년
# 공약 : 산학협력으로 도심형 청년일자리 구축
# 포함 키워드 : 일자리
# 공약 : 산학협력으로 도심형 청년일자리 구축
# 포함 키워드 : 자리
# 공약 : 산학협력으로 도심형 청년일자리 구축
# 포함 키워드 : 일자리
# 공약 : 도심형 첨년 일자리 확대
# 포함 키워드 : 자리
# 공약 : 도심형 첨년 일자리 확대
# 포함 키워드 : 일자리
# 공약 : 스마트형 4차산업 일자리 확충
# 포함 키워드 : 자리
# 공약 : 스마트형 4차산업 일자리 확충
# 포함 키워드 : 세대
# 공약 : 세대맞춤형 특화일자리 창출
# 포함 키워드 : 일자리
# 공약 : 세대맞춤형 특화일자리 창출
# 포함 키워드 : 자리
# 공약 : 세대맞춤형 특화일자리 창출
# 포함 키워드 : 부산
# 공약 : 부산 특화산업 일자리 조성
# 포함 키워드 : 일자리
# 공약 : 부산 특화산업 일자리 조성
# 포함 키워드 : 자리
# 공약 : 부산 특화산업 일자리 조성
# 포함 키워드 : 경제
# 공약 : 데이터기반 경제로 인공지능 산업 육성
# 포함 키워드 : 시민
# 공약 : 15분도시로 편리한 시민생활 보장
# 포함 키워드 : 15
# 공약 : 15분도시로 편리한 시민생활 보장
# 포함 키워드 : 민생
# 공약 : 15분도시로 편리한 시민생활 보장
# 포함 키워드 : 50
# 공약 : 50개 생활권별 공공시설 대폭 조성
# 포함 키워드 : 주택
# 공약 : 도시기반시설 재조정을 통한 적정주택 공급
# 포함 키워드 : 10
# 공약 : 10만호 노후아파트 리모델링 지원
# 포함 키워드 : 지원
# 공약 : 10만호 노후아파트 리모델링 지원
# 포함 키워드 : 아파트
# 공약 : 10만호 노후아파트 리모델링 지원
# 포함 키워드 : 추진
# 공약 : 사전타당성 조사를 위한 기초연구 즉시 추진
# 포함 키워드 : 부산
# 공약 : 부산의 문화와 일상의 품격을 한단계 격상
# 포함 키워드 : 15
# 공약 : 권역별 15분내 생활체육시설 대폭 조성
# 포함 키워드 : 부산
# 공약 : 부산오페라하우스 활성화를 위한 오페라 페스티벌 유치
# 포함 키워드 : 여성
# 공약 : 고품질 복지로 여성과 아이들이 행복한 부산
# 포함 키워드 : 부산
# 공약 : 고품질 복지로 여성과 아이들이 행복한 부산
# 포함 키워드 : 이들
# 공약 : 고품질 복지로 여성과 아이들이 행복한 부산
# 포함 키워드 : 추진
# 공약 : 정자,난자 보관은행 운영사업추진
# 포함 키워드 : 추진
# 공약 : 영유마 돌봄 확대사업 추진
# 포함 키워드 : 청년
# 공약 : 청년신용불량 구제지원
# 포함 키워드 : 지원
# 공약 : 청년신용불량 구제지원
# [3,
#  1,
#  1,
#  0,
#  1,
#  3,
#  3,
#  5,
#  5,
#  2,
#  1,
#  0,
#  2,
#  0,
#  2,
#  1,
#  1,
#  0,
#  0,
#  2,
#  1,
#  3,
#  0,
#  3,
#  3,
#  1,
#  2,
#  1,
#  0,
#  0,
#  0,
#  1,
#  0,
#  3,
#  2,
#  2,
#  1,
#  0,
#  0,
#  1,
#  3,
#  2,
#  1,
#  2,
#  3,
#  1,
#  3,
#  1,
#  1,
#  0,
#  1,
#  3,
#  1,
#  0,
#  1,
#  2,
#  1,
#  2,
#  0,
#  2,
#  0,
#  1,
#  1,
#  1,
#  0,
#  1,
#  5,
#  1,
#  2,
#  1,
#  1,
#  1,
#  3,
#  2,
#  2,
#  3,
#  3,
#  1,
#  3,
#  1,
#  0,
#  1,
#  3,
#  0,
#  1,
#  0,
#  1,
#  0,
#  1,
#  0,
#  1,
#  3,
#  0,
#  1,
#  1,
#  0,
#  2]

# %% [markdown]
# # 후보공약에 keyword_count 컬럼 추가한 df 생성

# %%
df = pledge
df['keyword_count'] = count
df
# Out:
#    name                                          pledge  keyword_count
# 0   박영선                21분 생활권 도시 서울, 세계 디지털 경제수도 서울 구현              3
# 1   박영선  21분안에 주거, 직장, 쇼핑., 여가, 건강, 의료, 교육, 보육이 해결되는 도시              1
# 2   박영선                                   강남 강북 균형발전 추진              1
# 3   박영선                                    대전환펀드 1조원 구성              0
# 4   박영선   블록체인 기술 기반 KS코인 운용. Al,5G 등 철단기술이 융합된 경제도시 조성              1
# ..  ...                                             ...            ...
# 92  박형준                                  저출산 예산 1조원대 증액              0
# 93  박형준                               정자,난자 보관은행 운영사업추진              1
# 94  박형준                                  영유마 돌봄 확대사업 추진              1
# 95  박형준                                        팸테크밸리 조성              0
# 96  박형준                                     청년신용불량 구제지원              2
#
# [97 rows x 3 columns]

# %% [markdown]
# # keyword_count 높은 순으로 보기

# %%
df.groupby('name').sum().sort_values(by='keyword_count',ascending=False)
# Out:
#       keyword_count
# name
# 박영선              37
# 김영춘              33
# 박형준              33
# 오세훈              32

# %% [markdown]
# - 결과 완전 엉터리
# - 개선 방향 생각해보자
