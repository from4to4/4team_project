# %%
import pandas as pd
from DaumNewsComment.DaumNews import getDaumNewsUrlDF
from DaumNewsComment.JoongangComments import getJoongangComment
from DaumNewsComment.DongaComments import getDongaComment
from DaumNewsComment.JTBCComments import getJTBCComment
from DaumNewsComment.KhanComments import getKhanComment
from DaumNewsComment.ChosunComments import getChosunComment

# %%
# 검색어
KEYWORD = '보궐선거'

# 언론
# 조선일보, 중앙일보, 동아일보, JTBC, 경향신문 택1
COLOPHON = '조선일보'

# 날짜 (YYYYMMDhhmmss)
dayStart = '20210407000000'
dayEnd   = '20210407200000'

# 기사 리스트 가져오기
df = getDaumNewsUrlDF(KEYWORD=KEYWORD, COLOPHON=COLOPHON, dayStart=dayStart, dayEnd=dayEnd, page=1)

# %%
#df = pd.read_csv('조선일보_link.csv')
getChosunComment(df)
# Out:
# 17번째 기사 댓글 수집 중
#                                  제목                  날짜                 작성일  \
# 0   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 16:39:12
# 1   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 16:34:30
# 2   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 16:08:36
# 3   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 15:05:06
# 4   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 14:51:51
# 5   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 14:21:12
# 6   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 13:06:40
# 7   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 12:31:38
# 8   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 11:05:07
# 9   박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 10:56:04
# 10  박영선 “거짓말 심판해달라” 오세훈 “시험대 통과하겠다” 2021-04-07 08:27:00 2021-04-07 10:53:39
# ...
