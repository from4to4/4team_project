# %%
import pandas as pd
from tqdm import tqdm

# %% [markdown]
# ## 데이터 불러오기

# %%
df = pd.read_csv('2030정치성향분석/data/data2030.csv')
df
# Out:
#        Unnamed: 0                                              Title  \
# 0               0                    #139​ 민주당 지도부가 2030 마음을 얻으려면...
# 1               1                    #139​ 민주당 지도부가 2030 마음을 얻으려면...
# 2               2                    #139​ 민주당 지도부가 2030 마음을 얻으려면...
# 3               3                    #139​ 민주당 지도부가 2030 마음을 얻으려면...
# 4               4                    #139​ 민주당 지도부가 2030 마음을 얻으려면...
# ...           ...                                                ...
# 56824       48635  [정치 맞수다] 대선가도 들어선 여·야의 서로 다른 잡음, 20대 남자 투표성향에 ...
# 56825       48636  [정치 맞수다] 대선가도 들어선 여·야의 서로 다른 잡음, 20대 남자 투표성향에 ...
# 56826       48637  [정치 맞수다] 대선가도 들어선 여·야의 서로 다른 잡음, 20대 남자 투표성향에 ...
# 56827       48638  [정치 맞수다] 대선가도 들어선 여·야의 서로 다른 잡음, 20대 남자 투표성향에 ...
# 56828       48639  [정치 맞수다] 대선가도 들어선 여·야의 서로 다른 잡음, 20대 남자 투표성향에 ...
#
#              Date          ID  \
# 0      2021-04-08       샤인디케이
# 1      2021-04-08         문동렬
# 2      2021-04-08    135 swan
# 3      2021-04-08          미루
# 4      2021-04-08         단아란
# ...           ...         ...
# 56824  2021-04-11         유창준
# 56825  2021-04-11         유정순
# 56826  2021-04-11  Hannah Kim
# 56827  2021-04-11         박계순
# 56828  2021-04-11        느티나무
#
#                                                  Comment Comment_date  \
# 0              내리막이 있으면 다시 오르막이 있는 법, 예방주사라 생각하고 힘들 냅시다.   2021-04-10
# 1      2030마음을 얻으려면 조언을 2030을 모셔다가 들어보는 성의를 보여야 됩니다. ...   2021-04-10
# 2      전 군대 전역 전까지는 보수를 지지했지만 대학에서 양극화에 관심을 가지면서 진보로 ...   2021-04-10
# 3      몸 안에서 무엇인가 무너져 내린 기분..그래도 힘내고 가야죠민주당은 뼈아픈 진단 새...   2021-04-10
# 4                                       네 죄송합니다. 삭제하겠습니다   2021-04-10
# ...                                                  ...          ...
# 56824            간교한 인간성을 가진,  김종인, 안띨수를 섬기느니..  죽는게 났다.   2021-04-17
# 56825             이준석 정치연륜이 뭐가있다고 이렇게 나와서 이야기를 많이 하고 다니나   2021-04-17
# 56826  준석아 주댕이 조심해라.안철수가 할말이 옳다. 단일화 못햇우면 오세훈 승라없엇다. ...   2021-04-17
# 56827                                         김준석  아웃 밉상   2021-04-17
# 56828                  토론자가 없어서 양문석, 이준석을 부르냐???한심하네~!!!   2021-04-17
#
#        Channel  Like Dislike Comment_like
# 0        박시영TV  6.4천      83           48
# 1        박시영TV  6.4천      83           37
# 2        박시영TV  6.4천      83           34
# 3        박시영TV  6.4천      83           67
# 4        박시영TV  6.4천      83           34
# ...        ...   ...     ...          ...
# 56824  MBCNEWS   615      88            1
# 56825  MBCNEWS   615      88            0
# 56826  MBCNEWS   615      88            0
# 56827  MBCNEWS   615      88            0
# 56828  MBCNEWS   615      88            0
#
# [56829 rows x 10 columns]

# %%
df_w = df['Comment']
df_w
# Out:
# 0                내리막이 있으면 다시 오르막이 있는 법, 예방주사라 생각하고 힘들 냅시다.
# 1        2030마음을 얻으려면 조언을 2030을 모셔다가 들어보는 성의를 보여야 됩니다. ...
# 2        전 군대 전역 전까지는 보수를 지지했지만 대학에서 양극화에 관심을 가지면서 진보로 ...
# 3        몸 안에서 무엇인가 무너져 내린 기분..그래도 힘내고 가야죠민주당은 뼈아픈 진단 새...
# 4                                         네 죄송합니다. 삭제하겠습니다
#                                ...
# 56824              간교한 인간성을 가진,  김종인, 안띨수를 섬기느니..  죽는게 났다.
# 56825               이준석 정치연륜이 뭐가있다고 이렇게 나와서 이야기를 많이 하고 다니나
# 56826    준석아 주댕이 조심해라.안철수가 할말이 옳다. 단일화 못햇우면 오세훈 승라없엇다. ...
# 56827                                           김준석  아웃 밉상
# 56828                    토론자가 없어서 양문석, 이준석을 부르냐???한심하네~!!!
# Name: Comment, Length: 56829, dtype: object

# %%
import re

# 텍스트 정제 함수 
def text_cleaning(text):
    # 한글 정규식 정의(띄어쓰기, ㄱ~ㅣ, 가~힣)
    hangul = re.compile('[^ ㄱ-ㅣ가-힣0-9a-zA-Z?!.,]+')
    # 정제한다(정규식에 해당하지 않는 문자는 길이가 0인 문자열로 변환한다)
    result = hangul.sub('', text)
    return result

# %%
df_w = df_w.apply(lambda x : text_cleaning(x))

# %%
# data 나누기
df_w1 = df_w[:5683]
df_w2 = df_w[5683:11366]
df_w3 = df_w[11366:17049]
df_w4 = df_w[17049:22732]
df_w5 = df_w[22732:28415]
df_w6 = df_w[28415:34098]
df_w7 = df_w[34098:39781]
df_w8 = df_w[39781:45464]
df_w9 = df_w[45464:51147]
df_w10 = df_w[51147:]

# %% [markdown]
# ## 데이터 전처리
# - 1. 명사분석
# - 2. 형용사분석
# - 3. 동사분석

# %% [markdown]
# ### 1. 명사분석

# %%
# 형태소 분석
from konlpy.tag import Okt

# 명사
def get_pos_noun(x) :
    tagger = Okt() # Okt로 형태소 분리하기
    pos = tagger.pos(x) 
    noun_list = []
    for i in pos:
        if i[1] == 'Noun':
#             print(i[0], i[1])
            noun_list.append(i[0])
    return noun_list

# %%
nouns1 = df_w1.apply(lambda x : get_pos_noun(x))
nouns2 = df_w2.apply(lambda x : get_pos_noun(x))
nouns3 = df_w3.apply(lambda x : get_pos_noun(x))
nouns4 = df_w4.apply(lambda x : get_pos_noun(x))
nouns5 = df_w5.apply(lambda x : get_pos_noun(x))
nouns6 = df_w6.apply(lambda x : get_pos_noun(x))
nouns7 = df_w7.apply(lambda x : get_pos_noun(x))
nouns8 = df_w8.apply(lambda x : get_pos_noun(x))
nouns9 = df_w9.apply(lambda x : get_pos_noun(x))
nouns10 = df_w10.apply(lambda x : get_pos_noun(x))

# %%
list_nouns1 = []
for n in nouns1 :
#     print(n)
    for x in n :
        list_nouns1.append(x)
        
list_nouns2 = []
for n in nouns2 :
#     print(n)
    for x in n :
        list_nouns2.append(x)
        
list_nouns3 = []
for n in nouns3 :
#     print(n)
    for x in n :
        list_nouns3.append(x)
        
list_nouns4 = []
for n in nouns4 :
#     print(n)
    for x in n :
        list_nouns4.append(x)
        
list_nouns5 = []
for n in nouns5 :
#     print(n)
    for x in n :
        list_nouns5.append(x)
        
list_nouns6 = []
for n in nouns6 :
#     print(n)
    for x in n :
        list_nouns6.append(x)
        
list_nouns7 = []
for n in nouns7 :
#     print(n)
    for x in n :
        list_nouns7.append(x)
        
list_nouns8 = []
for n in nouns8 :
#     print(n)
    for x in n :
        list_nouns8.append(x)
        
list_nouns9 = []
for n in nouns9 :
#     print(n)
    for x in n :
        list_nouns9.append(x)
        
list_nouns10 = []
for n in nouns10 :
#     print(n)
    for x in n :
        list_nouns10.append(x)

# %%
# 전체 갯수
nouns_all = list_nouns1 + list_nouns2 +list_nouns3 + list_nouns4 +list_nouns5 + list_nouns6 +list_nouns7 + list_nouns8 + list_nouns9 + list_nouns10
len(nouns_all)
# Out:
# 704736

# %%
# 한 글자 제거
nouns_words = []
for n in nouns_all :
    if len(n) > 1 :
        nouns_words.append(n)

# %%
# 불용어 제거
with open('politics_stopwords_nouns.txt', encoding='utf-8') as fp :
    stopwords = fp.readlines()

# \n 제거
stopwords = [x.strip() for x in stopwords]

remove_nouns_words = []
for key in nouns_words :
    # 현재 글자가 불용어에 포함되어 있지 않다면..
    if key not in stopwords :
        remove_nouns_words.append(key)

# %%
# 개수
from collections import Counter
nouns_count = Counter(remove_nouns_words)

# %% [markdown]
# ### 2. 형용사분석

# %%
# 형태소 분석
from konlpy.tag import Okt

# 명사
def get_pos_adjective(x) :
    tagger = Okt() # Okt로 형태소 분리하기
    pos = tagger.pos(x) 
    adjective_list = []
    for i in pos:
        if i[1] == 'Adjective':
#             print(i[0], i[1])
            adjective_list.append(i[0])
    return adjective_list

# %%
adjective1 = df_w1.apply(lambda x : get_pos_adjective(x))
adjective2 = df_w2.apply(lambda x : get_pos_adjective(x))
adjective3 = df_w3.apply(lambda x : get_pos_adjective(x))
adjective4 = df_w4.apply(lambda x : get_pos_adjective(x))
adjective5 = df_w5.apply(lambda x : get_pos_adjective(x))
adjective6 = df_w6.apply(lambda x : get_pos_adjective(x))
adjective7 = df_w7.apply(lambda x : get_pos_adjective(x))
adjective8 = df_w8.apply(lambda x : get_pos_adjective(x))
adjective9 = df_w9.apply(lambda x : get_pos_adjective(x))
adjective10 = df_w10.apply(lambda x : get_pos_adjective(x))

# %%
list_adjective1 = []
for n in adjective1 :
#     print(n)
    for x in n :
        list_adjective1.append(x)
        
list_adjective2 = []
for n in adjective2 :
#     print(n)
    for x in n :
        list_adjective2.append(x)
        
list_adjective3 = []
for n in adjective3 :
#     print(n)
    for x in n :
        list_adjective3.append(x)
        
list_adjective4 = []
for n in adjective4 :
#     print(n)
    for x in n :
        list_adjective4.append(x)
        
list_adjective5 = []
for n in adjective5 :
#     print(n)
    for x in n :
        list_adjective5.append(x)
        
list_adjective6 = []
for n in adjective6 :
#     print(n)
    for x in n :
        list_adjective6.append(x)
        
list_adjective7 = []
for n in adjective7 :
#     print(n)
    for x in n :
        list_adjective7.append(x)
        
list_adjective8 = []
for n in adjective8 :
#     print(n)
    for x in n :
        list_adjective8.append(x)
        
list_adjective9 = []
for n in adjective9 :
#     print(n)
    for x in n :
        list_adjective9.append(x)
        
list_adjective10 = []
for n in adjective10 :
#     print(n)
    for x in n :
        list_adjective10.append(x)

# %%
# 전체 갯수
adjective_all = list_adjective1 + list_adjective2 +list_adjective3 + list_adjective4 +list_adjective5 + list_adjective6 +list_adjective7 + list_adjective8 + list_adjective9 + list_adjective10
len(adjective_all)
# Out:
# 99728

# %%
# 한 글자 제거
adjective_words = []
for n in adjective_all :
    if len(n) > 1 :
        adjective_words.append(n)

# %%
# 불용어 제거
with open('politics_stopwords_adjective.txt', encoding='utf-8') as fp :
    stopwords = fp.readlines()

# \n 제거
stopwords = [x.strip() for x in stopwords]

remove_adjective_words = []
for key in adjective_words :
    # 현재 글자가 불용어에 포함되어 있지 않다면..
    if key not in stopwords :
        remove_adjective_words.append(key)

# %%
# 개수
from collections import Counter
adjective_count = Counter(remove_adjective_words)

# %% [markdown]
# ### 3. 동사분석

# %%
# 형태소 분석
from konlpy.tag import Okt

# 명사
def get_pos_verb(x) :
    tagger = Okt() # Okt로 형태소 분리하기
    pos = tagger.pos(x) 
    verb_list = []
    for i in pos:
        if i[1] == 'Verb':
#             print(i[0], i[1])
            verb_list.append(i[0])
    return verb_list

# %%
verb1 = df_w1.apply(lambda x : get_pos_verb(x))
verb2 = df_w2.apply(lambda x : get_pos_verb(x))
verb3 = df_w3.apply(lambda x : get_pos_verb(x))
verb4 = df_w4.apply(lambda x : get_pos_verb(x))
verb5 = df_w5.apply(lambda x : get_pos_verb(x))
verb6 = df_w6.apply(lambda x : get_pos_verb(x))
verb7 = df_w7.apply(lambda x : get_pos_verb(x))
verb8 = df_w8.apply(lambda x : get_pos_verb(x))
verb9 = df_w9.apply(lambda x : get_pos_verb(x))
verb10 = df_w10.apply(lambda x : get_pos_verb(x))

# %%
list_verb1 = []
for n in verb1 :
#     print(n)
    for x in n :
        list_verb1.append(x)
        
list_verb2 = []
for n in verb2 :
#     print(n)
    for x in n :
        list_verb2.append(x)
        
list_verb3 = []
for n in verb3 :
#     print(n)
    for x in n :
        list_verb3.append(x)
        
list_verb4 = []
for n in verb4 :
#     print(n)
    for x in n :
        list_verb4.append(x)
        
list_verb5 = []
for n in verb5 :
#     print(n)
    for x in n :
        list_verb5.append(x)
        
list_verb6 = []
for n in verb6 :
#     print(n)
    for x in n :
        list_verb6.append(x)
        
list_verb7 = []
for n in verb7 :
#     print(n)
    for x in n :
        list_verb7.append(x)
        
list_verb8 = []
for n in verb8 :
#     print(n)
    for x in n :
        list_verb8.append(x)
        
list_verb9 = []
for n in verb9 :
#     print(n)
    for x in n :
        list_verb9.append(x)
        
list_verb10 = []
for n in verb10 :
#     print(n)
    for x in n :
        list_verb10.append(x)

# %%
# 전체 갯수
verb_all = list_verb1 + list_verb2 +list_verb3 + list_verb4 +list_verb5 + list_verb6 +list_verb7 + list_verb8 + list_verb9 + list_verb10
len(verb_all)
# Out:
# 235221

# %%
# 한 글자 제거
verb_words = []
for n in verb_all :
    if len(n) > 1 :
        verb_words.append(n)

# %%
# 불용어 제거
with open('politics_stopwords_verb.txt', encoding='utf-8') as fp :
    stopwords = fp.readlines()

# \n 제거
stopwords = [x.strip() for x in stopwords]

remove_verb_words = []
for key in verb_words :
    # 현재 글자가 불용어에 포함되어 있지 않다면..
    if key not in stopwords :
        remove_verb_words.append(key)

# %%
# 개수
from collections import Counter
verb_count = Counter(remove_verb_words)

# %% [markdown]
# ## 결과
# - 1. 명사결과
# - 2. 형용사결과
# - 3. 동사결과

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
import platform

if platform.system() == 'Windows':  
    font_path = "c:/Windows/Fonts/malgun.ttf"
else:
    pass

# %% [markdown]
# ### 1.명사결과
# - 1-1. 명사 빈출단어
# - 1-2. 명사 워드클라우드

# %% [markdown]
# 1-1. 명사 빈출단어

# %%
# 빈출단어 500개
nouns_top500 = nouns_count.most_common(500) #500개

# 딕셔너리 전환
nouns_dict_top500 = {}
for x,y  in nouns_top500 :
    nouns_dict_top500[x] = y
    
nouns_dict_top500
# Out:
# {'민주당': 7823,
#  '페미': 5457,
#  '사람': 5265,
#  '국민': 5162,
#  '생각': 5159,
#  '여성': 4678,
#  '남자': 4341,
#  '남성': 3975,
#  '지금': 3267,
#  '보수': 2916,
#  '나라': 2884,
#  '오세훈': 2644,
#  '세대': 2601,
#  '정치': 2544,
#  '투표': 2519,
#  '문제': 2480,
#  '여자': 2480,
#  '선거': 2330,
#  '정책': 2302,
#  '정권': 2283,
#  '진보': 2245,
#  '지지': 2229,
#  '청년': 2193,
#  '정부': 2036,
#  '대통령': 2029,
#  '문재인': 1940,
#  '사회': 1857,
#  '언론': 1835,
#  '대한민국': 1615,
#  '부동산': 1608,
#  '이유': 1582,
#  '보고': 1505,
#  '개혁': 1466,
#  '대가': 1399,
#  '박영선': 1390,
#  '대선': 1374,
#  '후보': 1336,
#  '영상': 1259,
#  '정신': 1213,
#  '지지율': 1199,
#  '대한': 1171,
#  '조국': 1146,
#  '페미니즘': 1107,
#  '소리': 1066,
#  '결과': 1055,
#  '국힘': 1040,
#  '미래': 989,
#  '정도': 987,
#  '서울': 933,
#  '의원': 933,
#  '왕토': 932,
#  '인간': 916,
#  '한국': 914,
#  '화이팅': 908,
#  '주식': 902,
#  '방송': 901,
#  '뉴스': 890,
#  '역사': 884,
#  '응원': 863,
#  '국가': 863,
#  '시장': 862,
#  '남녀': 861,
#  '이해': 851,
#  '갈등': 851,
#  '세상': 842,
#  '좌파': 819,
#  '얘기': 806,
#  '코로나': 789,
#  '시민': 787,
#  '평등': 777,
#  '군대': 770,
#  '정당': 769,
#  '일베': 753,
#  '정치인': 748,
#  '말씀': 744,
#  '검찰': 743,
#  '사실': 738,
#  '시작': 732,
#  '여당': 726,
#  '우리나라': 722,
#  '취업': 717,
#  '세금': 710,
#  '분석': 707,
#  '박근혜': 706,
#  '투기': 705,
#  '이야기': 704,
#  '현실': 701,
#  '관심': 694,
#  '정의': 690,
#  '차별': 689,
#  '본인': 687,
#  '세력': 678,
#  '선택': 677,
#  '젊은이': 664,
#  '시대': 659,
#  '공감': 656,
#  '이재명': 629,
#  '허경영': 624,
#  '집단': 614,
#  '회사': 611,
#  '조작': 609,
#  '기회': 608,
#  '이준석': 605,
#  '공정': 603,
#  '수준': 599,
#  '대표': 597,
#  '거지': 593,
#  '민주': 592,
#  '댓글': 590,
#  '서울시장': 586,
#  '상황': 584,
#  '자체': 577,
#  '선동': 573,
#  '심판': 571,
#  '적폐': 570,
#  '잘못': 566,
#  '마음': 563,
#  '야당': 561,
#  '사건': 556,
#  '자유': 552,
#  '집값': 543,
#  '경제': 529,
#  '반대': 529,
#  '공부': 528,
#  '프로': 526,
#  '투자': 523,
#  '분노': 521,
#  '국회의원': 520,
#  '최고': 520,
#  '능력': 513,
#  '내년': 506,
#  '여가부': 505,
#  '혐오': 505,
#  '논리': 494,
#  '무시': 493,
#  '경험': 492,
#  '역차별': 492,
#  '우파': 492,
#  '경험치': 490,
#  '부정선거': 488,
#  '윤석열': 485,
#  '장관': 484,
#  '나이': 482,
#  '사태': 481,
#  '민주주의': 476,
#  '국짐': 474,
#  '인정': 470,
#  '목소리': 464,
#  '기득권': 463,
#  '조사': 460,
#  '폐지': 460,
#  '피해': 460,
#  '권력': 459,
#  '혜택': 458,
#  '젠더': 456,
#  '관련': 455,
#  '반성': 454,
#  '중국': 454,
#  '오늘': 445,
#  '친구': 437,
#  '주장': 435,
#  '당선': 430,
#  '비리': 428,
#  '해결': 424,
#  '초선': 417,
#  '북한': 415,
#  '쓰레기': 414,
#  '희생': 410,
#  '일자리': 409,
#  '인생': 407,
#  '노력': 406,
#  '모습': 406,
#  '일본': 406,
#  '미국': 403,
#  '취급': 401,
#  '거짓말': 401,
#  '공무원': 399,
#  '피해자': 398,
#  '부정': 393,
#  '주의': 393,
#  '군가산점': 393,
#  '성추행': 389,
#  '의견': 388,
#  '원인': 387,
#  '의미': 384,
#  '결혼': 383,
#  '아들': 382,
#  '차이': 380,
#  '내용': 378,
#  '개인': 377,
#  '과거': 377,
#  '촛불': 375,
#  '교육': 373,
#  '기업': 372,
#  '단체': 369,
#  '부산': 368,
#  '국회': 368,
#  '가짜': 367,
#  '가산': 366,
#  '발언': 365,
#  '민심': 363,
#  '아파트': 363,
#  '추미애': 362,
#  '지지자': 361,
#  '행동': 361,
#  '책임': 358,
#  '처음': 358,
#  '이슈': 355,
#  '서로': 354,
#  '정보': 354,
#  '공약': 353,
#  '팩트': 351,
#  '걱정': 351,
#  '희망': 349,
#  '부분': 347,
#  '편의점': 346,
#  '승리': 344,
#  '자리': 344,
#  '이익': 344,
#  '성별': 344,
#  '과정': 343,
#  '여론조사': 340,
#  '정상': 340,
#  '이명박': 340,
#  '머리': 339,
#  '세계': 337,
#  '성향': 336,
#  '판단': 336,
#  '집권': 334,
#  '페미니스트': 334,
#  '기억': 331,
#  '세월호': 331,
#  '거리': 328,
#  '퇴사': 328,
#  '대의': 326,
#  '이용': 325,
#  '인터넷': 324,
#  '존재': 323,
#  '불공정': 317,
#  '총선': 316,
#  '위선': 316,
#  '토론': 313,
#  '의무': 307,
#  '상식': 307,
#  '직장': 306,
#  '가족': 305,
#  '이낙연': 304,
#  '조직': 304,
#  '서민': 303,
#  '준비': 303,
#  '지원': 302,
#  '연설': 302,
#  '비판': 301,
#  '사전투표': 299,
#  '유튜브': 298,
#  '학생': 298,
#  '박원순': 297,
#  '거짓': 297,
#  '최악': 296,
#  '입장': 295,
#  '할당': 293,
#  '탄핵': 290,
#  '주변': 288,
#  '여론': 288,
#  '언급': 288,
#  '어차피': 288,
#  '바보': 288,
#  '설명': 287,
#  '의원님': 287,
#  '주택': 286,
#  '보상': 286,
#  '시절': 286,
#  '보기': 285,
#  '안철수': 285,
#  '의식': 284,
#  '사랑': 284,
#  '중도': 284,
#  '이념': 282,
#  '운동': 281,
#  '표심': 279,
#  '박형준': 278,
#  '가치': 278,
#  '평생': 278,
#  '지역': 277,
#  '고생': 276,
#  '전쟁': 276,
#  '진영': 274,
#  '권리': 274,
#  '진심': 272,
#  '방법': 272,
#  '수사': 271,
#  '민주화': 271,
#  '실제': 271,
#  '사과': 268,
#  '이후': 265,
#  '증거': 260,
#  '사고': 259,
#  '직접': 257,
#  '수도': 256,
#  '유지': 253,
#  '자식': 250,
#  '표현': 248,
#  '다행': 247,
#  '할아버지': 247,
#  '기자': 246,
#  '통계': 246,
#  '교체': 245,
#  '알바': 245,
#  '홍준표': 245,
#  '핵심': 245,
#  '발전': 244,
#  '우대': 244,
#  '포기': 242,
#  '경찰': 241,
#  '느낌': 240,
#  '사면': 240,
#  '시위': 240,
#  '정작': 239,
#  '필요': 238,
#  '시장님': 236,
#  '시기': 236,
#  '새끼': 236,
#  '원금': 235,
#  '아침': 235,
#  '월급': 234,
#  '프레임': 233,
#  '독재': 233,
#  '이득': 233,
#  '처럼': 232,
#  '이기': 231,
#  '대가리': 231,
#  '존경': 230,
#  '눈치': 229,
#  '생활': 228,
#  '교수': 228,
#  '군인': 227,
#  '마지막': 227,
#  '대학': 226,
#  '감사': 226,
#  '이름': 226,
#  '영선': 226,
#  '보도': 225,
#  '살기': 223,
#  '인식': 222,
#  '기사': 222,
#  '통해': 222,
#  '채널': 221,
#  '범죄': 221,
#  '재산': 219,
#  '안보': 218,
#  '폭등': 218,
#  '검사': 217,
#  '인권': 217,
#  '대체': 216,
#  '사퇴': 216,
#  '인물': 216,
#  '하루': 215,
#  '실패': 215,
#  '파악': 214,
#  '현상': 214,
#  '수가': 212,
#  '단어': 212,
#  '노예': 211,
#  '수고': 211,
#  '사상': 211,
#  '성차별': 211,
#  '대학생': 210,
#  '백신': 210,
#  '상태': 210,
#  '사기': 209,
#  '원래': 209,
#  '비율': 209,
#  '수박': 208,
#  '부자': 208,
#  '노무현': 207,
#  '박탈': 207,
#  '눈물': 207,
#  '양심': 205,
#  '코인': 204,
#  '불만': 203,
#  '이면': 203,
#  '갈라': 203,
#  '평가': 202,
#  '도움': 202,
#  '개돼지': 202,
#  '도쿄': 202,
#  '기본': 201,
#  '참고': 201,
#  '출신': 201,
#  '보이': 200,
#  '부모': 200,
#  '가면': 200,
#  '문화': 200,
#  '개판': 200,
#  '전체': 199,
#  '기성세대': 199,
#  '진실': 198,
#  '얼굴': 197,
#  '신경': 197,
#  '출마': 197,
#  '인터뷰': 196,
#  '대상': 196,
#  '재앙': 196,
#  '착각': 195,
#  '조장': 195,
#  '도둑': 193,
#  '싸움': 192,
#  '거나': 192,
#  '청산': 191,
#  '보궐선거': 191,
#  '방역': 190,
#  '일부': 189,
#  '참여': 188,
#  '패배': 187,
#  '약자': 186,
#  '패널': 186,
#  '이자': 186,
#  '고민': 185,
#  '정치권': 185,
#  '변화': 185,
#  '결정': 185,
#  '경쟁': 184,
#  '기준': 184,
#  '가야': 183,
#  '노인': 183,
#  '전라도': 183,
#  '하자': 182,
#  '관리': 182,
#  '감성': 181,
#  '상대': 181,
#  '시스템': 181,
#  '선생님': 180,
#  '학교': 180,
#  '환경': 179,
#  '태극기': 179,
#  '헛소리': 178,
#  '엄마': 178,
#  '하니': 178,
#  '사회주의': 178,
#  '교회': 178,
#  '지난': 177,
#  '처벌': 177,
#  '마찬가지': 177,
#  '순간': 177,
#  '윤미향': 176,
#  '개표': 176,
#  '김종인': 176,
#  '합리': 176,
#  '짓거리': 175,
#  '외면': 175,
#  '운동권': 175,
#  '동의': 175,
#  '가슴': 175,
#  '감옥': 175,
#  '부패': 175,
#  '법안': 173,
#  '지도': 173,
#  '대출': 173,
#  '복지': 172,
#  '서울시': 172,
#  '유권자': 171,
#  '로서': 171,
#  '아예': 171,
#  '불법': 171,
#  '역대': 171,
#  '점점': 170,
#  '공격': 170,
#  '제목': 169,
#  '영향': 169,
#  '실망': 169,
#  '기분': 168,
#  '결론': 168,
#  '손절': 168,
#  '성인': 168,
#  '활동': 167,
#  '무능': 167,
#  '개념': 166,
#  '비난': 165,
#  '확인': 165,
#  '지랄': 164,
#  '왕토좌': 164,
#  '통합': 163,
#  '정리': 163,
#  '부모님': 163,
#  '후회': 162,
#  '부대': 162,
#  '전문가': 160,
#  '진정': 160,
#  '처리': 160,
#  '구독': 160,
#  '기대': 160,
#  '직원': 160,
#  '적극': 159,
#  '기적': 159,
#  '왜구': 159,
#  '래야': 158,
#  '게임': 158,
#  '마인드': 158,
#  '제도': 158,
#  '토착': 158}

# %%
# 빈출단어 10개
nouns_dict_top10 = nouns_count.most_common(10)
nouns_dict_top10
# Out:
# [('민주당', 7823),
#  ('페미', 5457),
#  ('사람', 5265),
#  ('국민', 5162),
#  ('생각', 5159),
#  ('여성', 4678),
#  ('남자', 4341),
#  ('남성', 3975),
#  ('지금', 3267),
#  ('보수', 2916)]

# %% [markdown]
# 1-2. 명사 워드클라우드

# %%
nouns_wordcloud = WordCloud(font_path = font_path,
                     stopwords=stopwords,
                     colormap = 'twilight',
                     background_color='white',
                     max_words=100,
                     relative_scaling=0.1,   
                     width=800,
                     height=400
                     ).generate(' '.join(nouns_dict_top500))

plt.figure(figsize=(15,10))  
plt.imshow(nouns_wordcloud)

# %% [markdown]
# ### 2.형용사결과
# - 2-1. 형용사 빈출단어
# - 2-2. 형용사 워드클라우드

# %% [markdown]
# 2-1. 형용사 빈출단어

# %%
# 빈출단어 500개
adjective_top500 = adjective_count.most_common(500)

# 딕셔너리 전환
adjective_dict_top500 = {}
for x,y  in adjective_top500 :
    adjective_dict_top500[x] = y
    
adjective_dict_top500
# Out:
# {'좋은': 1029,
#  '미친': 246,
#  '나쁜': 225,
#  '좋아서': 205,
#  '좋아요': 204,
#  '힘든': 180,
#  '고맙습니다': 173,
#  '싫어서': 150,
#  '멋진': 134,
#  '무능한': 132,
#  '싫다': 117,
#  '더러운': 103,
#  '힘들게': 93,
#  '좋아하는': 91,
#  '멍청한': 87,
#  '똑똑하고': 87,
#  '한심한': 81,
#  '시원하게': 78,
#  '좋습니다': 78,
#  '힘들고': 76,
#  '싫어하는': 70,
#  '훌륭한': 70,
#  '어려운': 69,
#  '한심하다': 68,
#  '대단한': 68,
#  '싫고': 66,
#  '행복한': 65,
#  '싫어': 62,
#  '힘들어': 61,
#  '좋다고': 59,
#  '싫어요': 59,
#  '좋고': 58,
#  '어렵게': 56,
#  '시원합니다': 56,
#  '힘든데': 55,
#  '무서운': 54,
#  '역겨운': 54,
#  '든든합니다': 53,
#  '역겹다': 51,
#  '힘들': 50,
#  '편하게': 50,
#  '좋겠어요': 49,
#  '자랑스러운': 49,
#  '재밌게': 49,
#  '쉬운': 48,
#  '현명한': 48,
#  '좋을': 47,
#  '아름답고': 47,
#  '싫다고': 46,
#  '자유롭게': 46,
#  '답답하다': 42,
#  '아니꼽게': 42,
#  '빠른': 41,
#  '미친듯이': 41,
#  '재밌는': 40,
#  '답답한': 39,
#  '멋져요': 38,
#  '자랑스럽습니다': 38,
#  '자랑스럽다': 37,
#  '정당한': 37,
#  '불쌍한': 37,
#  '망하는': 36,
#  '착한': 36,
#  '강력하게': 36,
#  '불리한': 36,
#  '무서워서': 35,
#  '실패한': 35,
#  '쓸데없는': 35,
#  '싫은': 35,
#  '시원하다': 35,
#  '안타깝습니다': 35,
#  '천박한': 35,
#  '싫은데': 35,
#  '중요하다': 33,
#  '평범한': 33,
#  '안되': 33,
#  '안타까운': 33,
#  '심한': 33,
#  '안타깝다': 33,
#  '어리석은': 33,
#  '똑같다': 33,
#  '망할': 33,
#  '아픈': 32,
#  '유리한': 32,
#  '답답합니다': 32,
#  '괜찮은': 32,
#  '고마워요': 32,
#  '행복하게': 32,
#  '어렵고': 32,
#  '멍청하게': 32,
#  '엉뚱한': 31,
#  '있었지만': 31,
#  '억울한': 31,
#  '무식한': 31,
#  '멀쩡한': 31,
#  '이상하게': 31,
#  '심하게': 30,
#  '중요합니다': 30,
#  '있기에': 30,
#  '새로': 30,
#  '정직한': 30,
#  '있지요': 30,
#  '시원한': 30,
#  '좋음': 30,
#  '똑같아': 30,
#  '싫음': 30,
#  '어렵다': 30,
#  '천박하고': 30,
#  '깊게': 29,
#  '다르지': 29,
#  '망한': 29,
#  '드럽게': 29,
#  '힘들다고': 29,
#  '안되니': 29,
#  '속상해': 29,
#  '사악한': 29,
#  '반갑습니다': 29,
#  '고마워': 29,
#  '망하게': 29,
#  '있을지': 29,
#  '바쁜': 28,
#  '위험한': 28,
#  '그렇기에': 28,
#  '싫지만': 28,
#  '만만한': 28,
#  '필요없다': 28,
#  '무능하고': 28,
#  '부끄럽지': 28,
#  '있었으면': 28,
#  '있는거지': 28,
#  '있는듯': 27,
#  '정신차려야': 27,
#  '미쳐': 27,
#  '궁금합니다': 27,
#  '싫으면': 27,
#  '계신': 27,
#  '아닌듯': 27,
#  '멋지십니다': 27,
#  '높게': 27,
#  '부끄럽다': 27,
#  '당당히': 27,
#  '미안하다': 27,
#  '없으면서': 27,
#  '없더라': 27,
#  '그러는': 27,
#  '아니잖아': 27,
#  '안된': 27,
#  '평화로운': 27,
#  '아니니': 27,
#  '있는것도': 26,
#  '어떨까': 26,
#  '입니다만': 26,
#  '야하지': 26,
#  '옳다': 26,
#  '무섭다': 26,
#  '계실': 26,
#  '평등하고': 26,
#  '똑같음': 26,
#  '힘들어서': 26,
#  '있겠냐': 26,
#  '옳다고': 26,
#  '다른거': 26,
#  '아니기': 26,
#  '불가능한': 26,
#  '민감한': 25,
#  '싫습니다': 25,
#  '좋네': 25,
#  '같으니': 25,
#  '안타깝네요': 25,
#  '더럽게': 25,
#  '위대한': 25,
#  '안되나': 25,
#  '불쌍하다': 25,
#  '안좋은': 25,
#  '궁금한게': 25,
#  '중요한건': 25,
#  '젊을': 25,
#  '재미있는': 24,
#  '짧은': 24,
#  '미는': 24,
#  '잘난': 24,
#  '적절한': 24,
#  '시원하네요': 24,
#  '완벽한': 24,
#  '궁금하다': 24,
#  '뿐이죠': 24,
#  '부족해서': 24,
#  '가볍게': 23,
#  '없나요': 23,
#  '낡은': 23,
#  '야한다는': 23,
#  '그만해라': 23,
#  '어떤지': 23,
#  '다르고': 23,
#  '있었다고': 23,
#  '안되요': 23,
#  '분노하는': 23,
#  '뛰어난': 23,
#  '있을수': 23,
#  '답답하네': 23,
#  '공평하게': 23,
#  '있겠죠': 23,
#  '같은게': 22,
#  '심각합니다': 22,
#  '정신차리세요': 22,
#  '망합니다': 22,
#  '당해도': 22,
#  '있으나': 22,
#  '그럴까': 22,
#  '재밌네요': 22,
#  '그렇습니다': 22,
#  '귀한': 22,
#  '싫어합니다': 22,
#  '비싼': 22,
#  '비리는': 22,
#  '없잖아': 22,
#  '시원하네': 22,
#  '많은걸': 22,
#  '궁금하네요': 21,
#  '필요하고': 21,
#  '심각하게': 21,
#  '분노하고': 21,
#  '부당한': 21,
#  '명확히': 21,
#  '멋있습니다': 21,
#  '똑똑해': 21,
#  '아름다운': 21,
#  '지겨워': 21,
#  '역겨워서': 21,
#  '심하고': 21,
#  '있을거': 21,
#  '발발하여도': 21,
#  '억울하신': 21,
#  '완벽하게': 21,
#  '재미있게': 21,
#  '사소한': 20,
#  '없을것이다': 20,
#  '엄중하게': 20,
#  '심심하면': 20,
#  '안되서': 20,
#  '흔히': 20,
#  '답답해서': 20,
#  '망해라': 20,
#  '안되죠': 20,
#  '힘들지만': 20,
#  '망해서': 20,
#  '대단합니다': 20,
#  '멋지고': 20,
#  '장하다': 20,
#  '스럽네요': 20,
#  '싫어도': 20,
#  '오래된': 20,
#  '원한다면': 20,
#  '편하고': 20,
#  '안되니까': 20,
#  '없을거다': 20,
#  '망했다': 20,
#  '아니면서': 20,
#  '아니네': 20,
#  '좋지만': 20,
#  '그러는데': 20,
#  '건전한': 20,
#  '부끄러운줄': 19,
#  '짜증나서': 19,
#  '없이는': 19,
#  '용감한': 19,
#  '없는듯': 19,
#  '당한다': 19,
#  '당하는게': 19,
#  '부끄러운': 19,
#  '있을것': 19,
#  '슬픈': 19,
#  '부족하고': 19,
#  '미쳤다고': 19,
#  '아니예요': 19,
#  '확실한건': 19,
#  '신기하다': 19,
#  '안되냐': 19,
#  '명쾌한': 19,
#  '같아도': 19,
#  '귀찮아서': 19,
#  '없지요': 19,
#  '안타깝고': 19,
#  '필요할': 18,
#  '치열하게': 18,
#  '아니잖아요': 18,
#  '확실합니다': 18,
#  '답답하네요': 18,
#  '곤란하고': 18,
#  '안되나요': 18,
#  '잘나서': 18,
#  '있겠지': 18,
#  '무서워': 18,
#  '있었죠': 18,
#  '똑똑하네요': 18,
#  '부럽다': 18,
#  '따뜻한': 18,
#  '없겠지만': 18,
#  '끔찍하다': 18,
#  '궁금해서': 18,
#  '정신차리지': 18,
#  '차가': 18,
#  '망해': 18,
#  '이쁜': 18,
#  '넘쳐': 18,
#  '싫어하고': 18,
#  '그러': 18,
#  '실망한': 18,
#  '슬프다': 18,
#  '답답하고': 18,
#  '불편한': 18,
#  '젊었을': 18,
#  '이런데도': 18,
#  '같은것': 18,
#  '비슷하게': 18,
#  '무거운': 18,
#  '중요하다고': 17,
#  '다를까': 17,
#  '명백한': 17,
#  '미친것': 17,
#  '상당한': 17,
#  '역겨워': 17,
#  '많은거': 17,
#  '대단하십니다': 17,
#  '멋지네요': 17,
#  '현명하고': 17,
#  '아니며': 17,
#  '같지만': 17,
#  '좁은': 17,
#  '많을': 17,
#  '힘들지': 17,
#  '솔직하게': 17,
#  '좋아합니다': 17,
#  '억울하고': 17,
#  '억울함을': 17,
#  '망하면': 17,
#  '묵묵히': 17,
#  '편히': 17,
#  '변할': 17,
#  '높아': 17,
#  '좋겠네': 17,
#  '당하기': 17,
#  '다르다고': 17,
#  '특별한': 17,
#  '계십니다': 16,
#  '길은': 16,
#  '심하세요': 16,
#  '귀중한': 16,
#  '좋으면': 16,
#  '힘듭니다': 16,
#  '힘들었고': 16,
#  '아니요': 16,
#  '정직하고': 16,
#  '뻔하다': 16,
#  '불행한': 16,
#  '든든하다': 16,
#  '뻔하지': 16,
#  '분노해서': 16,
#  '깔끔하게': 16,
#  '중대한': 16,
#  '아니까': 16,
#  '안전한': 16,
#  '억울함': 16,
#  '공정할': 16,
#  '힘없는': 16,
#  '분노한다': 16,
#  '힘드네요': 16,
#  '좋겠다고': 16,
#  '안되게': 16,
#  '없는거야': 16,
#  '멍청해서': 16,
#  '충분한': 16,
#  '대단해': 16,
#  '있었지': 16,
#  '힘들다는': 16,
#  '유리하게': 16,
#  '반가운': 16,
#  '있군요': 16,
#  '높으면': 16,
#  '복잡한': 16,
#  '좋겠음': 15,
#  '싫어함': 15,
#  '아프고': 15,
#  '부패하고': 15,
#  '강하고': 15,
#  '짧게': 15,
#  '간단히': 15,
#  '분노한': 15,
#  '심히': 15,
#  '어설프게': 15,
#  '싫어하는데': 15,
#  '계셔서': 15,
#  '대단하네': 15,
#  '아쉽습니다': 15,
#  '있답니다': 15,
#  '명확한': 15,
#  '좋아할': 15,
#  '정신차리자': 15,
#  '분노할': 15,
#  '부끄러워': 15,
#  '더하면': 15,
#  '미를': 15,
#  '그런데도': 15,
#  '없었으면': 15,
#  '부끄럽습니다': 15,
#  '바람직한': 15,
#  '힘든게': 15,
#  '서러운': 15,
#  '빡쳐서': 15,
#  '이상하다': 15,
#  '무능력한': 15,
#  '이상한거': 15,
#  '즐겁게': 15,
#  '있겠다': 15,
#  '약한': 15,
#  '같았는데': 15,
#  '기대하고': 15,
#  '스러울': 15,
#  '없는건': 15,
#  '높다고': 15,
#  '뻔하고': 15,
#  '있는데도': 15,
#  '있었을': 15,
#  '좋다는': 15,
#  '불편하면': 15,
#  '원하고': 15,
#  '힘들듯': 15,
#  '없거든': 15,
#  '원하는게': 15,
#  '비겁한': 15,
#  '냉정하게': 15,
#  '있구요': 15,
#  '아프다': 15,
#  '없었다는': 15,
#  '많이하고': 15,
#  '많으니': 14,
#  '있겠네요': 14,
#  '완전한': 14,
#  '같죠': 14,
#  '안되네요': 14,
#  '야해요': 14,
#  '후련합니다': 14,
#  '힘차게': 14,
#  '있었다는': 14,
#  '아니었나': 14,
#  '변함': 14,
#  '열렬히': 14,
#  '많으셨습니다': 14,
#  '있었': 14,
#  '머니': 14,
#  '부럽습니다': 14,
#  '자랑스런': 14,
#  '탁월한': 14,
#  '어떤게': 14,
#  '불안하다': 14,
#  '신기하네': 14,
#  '아니겠지': 14,
#  '있는거다': 14,
#  '아닐텐데': 14,
#  '있어라': 14,
#  '안되네': 14,
#  '검은': 14,
#  '열등한': 14,
#  '두려워': 14,
#  '낮아': 14,
#  '궁금했는데': 14,
#  '편한': 14,
#  '옳을': 14,
#  '저급한': 14,
#  '그렇게도': 14,
#  '명확하게': 14,
#  '많은것': 14,
#  '명백히': 14,
#  '행복하세요': 14,
#  '어떡하지': 14,
#  '못지않게': 13,
#  '야할듯': 13,
#  '젊고': 13,
#  '싫어한다': 13,
#  '많았음': 13,
#  '안타깝지만': 13,
#  '간단한데': 13,
#  '실망했다': 13,
#  '어이없는': 13,
#  '미치지': 13,
#  '안타까': 13,
#  '있잖아요': 13,
#  '똑같습니다': 13,
#  '어설픈': 13,
#  '대단히': 13,
#  '원하는지': 13,
#  '대단하네요': 13,
#  '좋았던': 13,
#  '힘든거': 13,
#  '같았으면': 13,
#  '짜증나': 13,
#  '당해야': 13,
#  '안일한': 13,
#  '평등하지': 13,
#  '있는걸': 13}

# %%
# 빈출단어 10개
adjective_dict_top10 = adjective_count.most_common(10)
adjective_dict_top10
# Out:
# [('좋은', 1029),
#  ('미친', 246),
#  ('나쁜', 225),
#  ('좋아서', 205),
#  ('좋아요', 204),
#  ('힘든', 180),
#  ('고맙습니다', 173),
#  ('싫어서', 150),
#  ('멋진', 134),
#  ('무능한', 132)]

# %% [markdown]
# 2-2. 형용사 워드클라우드

# %%
adjective_wordcloud = WordCloud(font_path = font_path,
                     stopwords=stopwords,
                     colormap = 'twilight',
                     background_color='white',
                     max_words=100,
                     relative_scaling=0.1,   
                     width=800,
                     height=400
                     ).generate(' '.join(adjective_dict_top500))

plt.figure(figsize=(15,10))  
plt.imshow(adjective_wordcloud)

# %% [markdown]
# ### 3.동사결과
# - 3-1. 동사 빈출단어
# - 3-2. 동사 워드클라우드

# %% [markdown]
# 3-1. 동사 빈출단어

# %%
# 빈출단어 500개
verb_top500 = verb_count.most_common(500)

# 딕셔너리 전환
verb_dict_top500 = {}
for x,y  in verb_top500 :
    verb_dict_top500[x] = y
    
verb_dict_top500
# Out:
# {'감사합니다': 992,
#  '바랍니다': 345,
#  '뽑아': 272,
#  '듣고': 265,
#  '쉽게': 255,
#  '받는': 253,
#  '받은': 241,
#  '만든': 239,
#  '찍어': 227,
#  '주세요': 215,
#  '주고': 212,
#  '뽑은': 201,
#  '쓰고': 193,
#  '뽑을': 185,
#  '믿고': 181,
#  '버리고': 181,
#  '아는': 178,
#  '때려': 168,
#  '찍은': 160,
#  '뽑는': 159,
#  '힘내세요': 155,
#  '맞습니다': 146,
#  '시켜': 144,
#  '악물고': 141,
#  '놓고': 140,
#  '만드는': 138,
#  '떠나서': 134,
#  '몰아': 129,
#  '갖고': 128,
#  '바란다': 122,
#  '쓰는': 121,
#  '뽑는다': 120,
#  '마시고': 116,
#  '보이는': 114,
#  '몰라서': 114,
#  '몰라': 110,
#  '찍는': 109,
#  '지키기': 106,
#  '썩은': 106,
#  '깨문': 106,
#  '시키는': 103,
#  '남은': 102,
#  '지켜': 101,
#  '돌려': 100,
#  '할거': 98,
#  '들어서': 98,
#  '다니는': 98,
#  '뽑으면': 98,
#  '않게': 97,
#  '찾아': 94,
#  '죽어도': 94,
#  '더듬어': 93,
#  '걸고': 92,
#  '내는': 92,
#  '몰라도': 92,
#  '겪어': 92,
#  '받아서': 91,
#  '나를': 91,
#  '지키는': 90,
#  '깨어있는': 89,
#  '바꿔': 88,
#  '가르기': 88,
#  '알아야': 86,
#  '뽑고': 85,
#  '먹은': 84,
#  '찍는다': 84,
#  '적은': 83,
#  '받아야': 83,
#  '끌어': 83,
#  '만들어서': 82,
#  '빠진': 82,
#  '느끼는': 80,
#  '뽑는게': 80,
#  '맞아': 79,
#  '찍고': 79,
#  '시켜라': 78,
#  '믿습니다': 78,
#  '차리고': 78,
#  '잡으면': 76,
#  '모른다': 76,
#  '봐요': 74,
#  '모르겠다': 74,
#  '아는데': 74,
#  '믿는': 72,
#  '준다': 72,
#  '없애고': 72,
#  '믿지': 72,
#  '버리는': 71,
#  '나간': 71,
#  '찍으면': 71,
#  '나가는': 71,
#  '바라는': 70,
#  '시킨': 69,
#  '바른': 69,
#  '모르겠지만': 69,
#  '되었고': 69,
#  '줬더니': 68,
#  '보여준': 68,
#  '돌린': 68,
#  '해주셔서': 68,
#  '주면': 67,
#  '되냐': 67,
#  '준다고': 66,
#  '차렸네': 64,
#  '느낀': 64,
#  '살아온': 64,
#  '뜨고': 63,
#  '쉽지': 63,
#  '막고': 62,
#  '모르나': 62,
#  '뽑은게': 62,
#  '벌고': 61,
#  '읽어': 61,
#  '뽑은거': 61,
#  '잃고': 60,
#  '듣는': 60,
#  '배우고': 60,
#  '챙겨': 60,
#  '태어나서': 60,
#  '주셔서': 60,
#  '떠나': 59,
#  '이긴': 59,
#  '모르네': 59,
#  '잡는': 58,
#  '받게': 58,
#  '알면서도': 58,
#  '맞는데': 58,
#  '끝나고': 58,
#  '비해': 57,
#  '알려': 57,
#  '나가서': 56,
#  '맞음': 56,
#  '뒤집어': 56,
#  '열린': 55,
#  '맞다고': 55,
#  '모아': 55,
#  '나서서': 55,
#  '찍음': 55,
#  '돌봄': 55,
#  '보소': 54,
#  '시켜야': 54,
#  '안다': 54,
#  '넘게': 54,
#  '겪은': 54,
#  '보여주는': 54,
#  '먹을': 53,
#  '알면서': 53,
#  '올리고': 53,
#  '걸러': 53,
#  '치는': 53,
#  '보고': 53,
#  '받으면서': 53,
#  '늙은': 53,
#  '얻을': 52,
#  '없애라': 52,
#  '이길': 51,
#  '살아야': 51,
#  '싸우는': 51,
#  '바뀔': 50,
#  '따른': 50,
#  '맞게': 50,
#  '믿어': 50,
#  '만들어놓고': 50,
#  '열면': 50,
#  '지는': 49,
#  '태어난': 49,
#  '떨어진': 48,
#  '크다': 48,
#  '찍지': 48,
#  '느껴': 48,
#  '속이는': 48,
#  '느낍니다': 47,
#  '썩어': 47,
#  '먹어': 47,
#  '해쳐': 47,
#  '일어나라': 47,
#  '돌아선': 46,
#  '쓰면': 46,
#  '들으면': 46,
#  '뽑아야': 46,
#  '떨어지는': 46,
#  '시켜서': 46,
#  '모아서': 45,
#  '끌려': 45,
#  '찍는게': 45,
#  '살다': 45,
#  '버려': 45,
#  '자란': 45,
#  '다는': 44,
#  '빠는': 44,
#  '모르지만': 44,
#  '바친': 44,
#  '넘는': 43,
#  '믿는다': 43,
#  '바꾸고': 43,
#  '받기': 43,
#  '돌아가는': 43,
#  '챙기고': 43,
#  '벌어': 43,
#  '대랑': 43,
#  '뚫어': 43,
#  '느낀다': 42,
#  '사는데': 42,
#  '돌리는': 42,
#  '감사해요': 42,
#  '배워': 42,
#  '나가면': 42,
#  '빼면': 42,
#  '애써': 42,
#  '얻어': 42,
#  '웃기는': 42,
#  '오면': 42,
#  '오르고': 41,
#  '터진': 41,
#  '쳐서': 41,
#  '이끌어': 41,
#  '뽑았다': 41,
#  '써서': 40,
#  '살아라': 40,
#  '살아있는': 40,
#  '잡은': 40,
#  '생긴': 40,
#  '않기': 40,
#  '누르고': 40,
#  '끝났다': 40,
#  '바뀌면': 40,
#  '올라': 39,
#  '늦게': 39,
#  '떨어져': 39,
#  '싸울': 39,
#  '얻은': 39,
#  '모르면': 39,
#  '잘사는': 39,
#  '털어': 39,
#  '듣지': 39,
#  '기울어진': 39,
#  '끝난': 39,
#  '가리지': 39,
#  '놀고': 38,
#  '웃고': 38,
#  '줬다': 38,
#  '바꿔야': 38,
#  '살아서': 38,
#  '찾고': 38,
#  '놀랍다': 38,
#  '살려': 38,
#  '얻고': 38,
#  '줬으면': 38,
#  '올려': 38,
#  '지키고': 37,
#  '만들면': 37,
#  '잃은': 37,
#  '들어간': 37,
#  '지나가는': 37,
#  '우습게': 37,
#  '생기는': 37,
#  '넣어': 37,
#  '떨어지고': 37,
#  '온다': 37,
#  '모르니': 37,
#  '쫒아': 37,
#  '웃긴게': 37,
#  '나눠서': 36,
#  '맞춰': 36,
#  '나가고': 36,
#  '뜯어': 36,
#  '물려': 36,
#  '고쳐': 36,
#  '죽어': 36,
#  '크지': 36,
#  '찍었다': 36,
#  '먹어도': 36,
#  '먹으면': 36,
#  '바라보는': 35,
#  '받는게': 35,
#  '싸우고': 35,
#  '바뀌지': 35,
#  '애쓴다': 35,
#  '맞네': 35,
#  '불리는': 35,
#  '믿을': 35,
#  '자빠졌네': 35,
#  '외치는': 35,
#  '다니고': 35,
#  '들지': 34,
#  '만들어야': 34,
#  '가지는': 34,
#  '모릅니다': 34,
#  '박고': 34,
#  '버리면': 34,
#  '타기': 34,
#  '뽑는거지': 34,
#  '크고': 34,
#  '모르겠고': 34,
#  '찍은게': 34,
#  '가리': 34,
#  '돌리고': 34,
#  '떠들어': 34,
#  '자는': 34,
#  '더듬당': 34,
#  '바뀌는': 33,
#  '뭉쳐서': 33,
#  '배운': 33,
#  '바라고': 33,
#  '나왔는데': 33,
#  '믿을수': 33,
#  '외치면서': 33,
#  '보여주고': 33,
#  '일어나야': 33,
#  '보낼': 33,
#  '줘도': 32,
#  '참다': 32,
#  '싸워': 32,
#  '세우고': 32,
#  '일어나면': 32,
#  '이긴다': 32,
#  '깨어': 32,
#  '모르게': 32,
#  '차이는': 32,
#  '갖다': 32,
#  '던질': 32,
#  '되었는데': 32,
#  '떨어진다고': 32,
#  '했을까': 31,
#  '보여주기': 31,
#  '터져': 31,
#  '풀어': 31,
#  '모르겠는데': 31,
#  '내리고': 31,
#  '끝나면': 31,
#  '몰랐다': 31,
#  '빠져서': 31,
#  '막아': 31,
#  '깨닫게': 31,
#  '만드는데': 31,
#  '오고': 31,
#  '막지': 31,
#  '더듬': 31,
#  '가져': 31,
#  '힘내라': 31,
#  '찍은거': 31,
#  '웃긴': 31,
#  '물어보면': 31,
#  '시키겠다': 31,
#  '빠져': 30,
#  '힘냅시다': 30,
#  '느끼게': 30,
#  '바꿀': 30,
#  '망친': 30,
#  '외치던': 30,
#  '모를': 30,
#  '사라지고': 30,
#  '없애야': 30,
#  '읽고': 30,
#  '뭉쳐': 30,
#  '차리세요': 30,
#  '밝다': 30,
#  '삶은': 30,
#  '드리겠습니다': 30,
#  '모르겠음': 30,
#  '겠네': 30,
#  '되겠네': 30,
#  '만들겠습니다': 30,
#  '맞서': 30,
#  '살아가고': 30,
#  '얻기': 30,
#  '무너지고': 30,
#  '떨어지면': 30,
#  '왔던': 29,
#  '모르겠습니다': 29,
#  '넣고': 29,
#  '모르는게': 29,
#  '막는': 29,
#  '들에게': 29,
#  '들이죠': 29,
#  '나가': 29,
#  '받아라': 29,
#  '대다': 29,
#  '일어날': 29,
#  '알기': 29,
#  '되시길': 29,
#  '보낸': 29,
#  '겪고': 29,
#  '생겨': 29,
#  '오길': 29,
#  '살아갈': 29,
#  '겠냐': 29,
#  '내세우는': 29,
#  '까고': 29,
#  '입은': 29,
#  '받았다': 29,
#  '외쳐': 29,
#  '파는': 29,
#  '뽑아야지': 29,
#  '버리네': 29,
#  '모르지': 29,
#  '참아': 29,
#  '지를': 29,
#  '가지고도': 28,
#  '버리지': 28,
#  '뽑아서': 28,
#  '삽니다': 28,
#  '차리네': 28,
#  '지킬': 28,
#  '일어나': 28,
#  '넘어서': 28,
#  '바뀐': 28,
#  '하지는': 28,
#  '틀린': 28,
#  '버려야': 28,
#  '빼고는': 28,
#  '보네요': 28,
#  '왔고': 28,
#  '따지고': 28,
#  '터지고': 28,
#  '받던': 28,
#  '보던': 28,
#  '하시는지': 28,
#  '끝날': 28,
#  '나온거': 28,
#  '하셨네요': 28,
#  '막아야': 28,
#  '대들을': 28,
#  '살아가는': 28,
#  '뽑아라': 28,
#  '맞으면': 28,
#  '죽어라': 28,
#  '들어가서': 28,
#  '묻고': 28,
#  '적게': 28,
#  '배워서': 28,
#  '되었다는': 28,
#  '없어져야': 28,
#  '몰린': 28,
#  '알겠지만': 28,
#  '몰고': 28,
#  '다닐': 28,
#  '움직이는': 28,
#  '그만두고': 28,
#  '입고': 27,
#  '심은': 27,
#  '하시지': 27,
#  '가네': 27,
#  '되었던': 27,
#  '떠나라': 27,
#  '찍습니다': 27,
#  '죽은': 27,
#  '하시나요': 27,
#  '잘한': 27,
#  '해야되': 27,
#  '않아도': 27,
#  '하기를': 27,
#  '일잘': 27,
#  '해보니': 27,
#  '대라': 27,
#  '하질': 27,
#  '세워': 27,
#  '주시길': 27,
#  '짓고': 27,
#  '갔는데': 27,
#  '하노': 27,
#  '대들에게': 27,
#  '부추기고': 27,
#  '가네요': 27,
#  '찍었는데': 27,
#  '하기엔': 27,
#  '됐고': 27,
#  '찾을': 27,
#  '깨어나야': 27,
#  '써도': 27,
#  '돌아간다': 27,
#  '가르고': 27,
#  '날라': 27,
#  '용기내어': 27,
#  '따르는게': 27,
#  '믿으면': 27,
#  '어딨냐': 26,
#  '모여': 26,
#  '들어주고': 26,
#  '남기': 26,
#  '알잖아': 26,
#  '차리자': 26,
#  '될거다': 26,
#  '집어': 26,
#  '찾아서': 26,
#  '키워': 26,
#  '가는데': 26,
#  '했니': 26,
#  '따져': 26,
#  '먹여': 26,
#  '뽑아주면': 26,
#  '나오는거': 26,
#  '찍었습니다': 26,
#  '하는듯': 26,
#  '줍시다': 26,
#  '나게': 26,
#  '먹었다': 26,
#  '이라': 26,
#  '되는것': 26,
#  '맞나': 26}

# %%
# 빈출단어 10개
verb_top10 = verb_count.most_common(10)
verb_top10
# Out:
# [('감사합니다', 992),
#  ('바랍니다', 345),
#  ('뽑아', 272),
#  ('듣고', 265),
#  ('쉽게', 255),
#  ('받는', 253),
#  ('받은', 241),
#  ('만든', 239),
#  ('찍어', 227),
#  ('주세요', 215)]

# %% [markdown]
# 3-2. 동사 워드클라우드

# %%
verb_wordcloud = WordCloud(font_path = font_path,
                     stopwords=stopwords,
                     colormap = 'twilight',
                     background_color='white',
                     max_words=100,
                     relative_scaling=0.1,   
                     width=800,
                     height=400
                     ).generate(' '.join(verb_dict_top500))

plt.figure(figsize=(15,10))  
plt.imshow(verb_wordcloud)
